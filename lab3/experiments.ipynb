# %% [markdown]
# ### Winning ratio with same search depths

# %% [markdown]
# ##### Max first

# %%
from play import play


pl1_win = 0
pl2_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(7,7, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        pl1_win += 1

    else:
        pl2_win += 1


print("Max was first")
print(f'Player1: {(pl1_win/iter)*100}%')
print(f'Player2: {(pl2_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# Max was first
# Player1: 53.333333333333336%
# Player2: 43.333333333333336%
# Draw: 3.3333333333333335%

# %%
from play import play


pl1_win = 0
pl2_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(4,4, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        pl1_win += 1

    else:
        pl2_win += 1


print("Max was first")
print(f'Player1: {(pl1_win/iter)*100}%')
print(f'Player2: {(pl2_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')

# %% [markdown]
# #### Random moves

# %%
import random
from two_player_games.player import Player
from two_player_games.games.connect_four import ConnectFourMove, ConnectFour, ConnectFourState

pl1_win = 0
pl2_win = 0
draw = 0
iter = 1000

for i in range(iter):
    player1 = Player("1")
    player2 = Player("2")
    game = ConnectFour((7,6), player1, player2)


    while not game.is_finished():

        index = random.randint(0,6)
        move = ConnectFourMove(index)
        game.make_move(move)


    winner = game.get_winner()

    if winner == None:
        draw += 1

    elif winner.char == "1":
        pl1_win += 1

    else:
        pl2_win += 1

print(f'Player1: {(pl1_win/iter)*100}%')
print(f'Player2: {(pl2_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')

# %% [markdown]
# #### Bigger depth for min

# %%
max_win = 0
min_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(4,7, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        max_win += 1

    else:
        min_win += 1



print(f'Player1: {(max_win/iter)*100}%')
print(f'Player2: {(min_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# Player1: 30.0%
# Player2: 66.66666666666666%
# Draw: 3.3333333333333335%

# %%
max_win = 0
min_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(3,8, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        max_win += 1

    else:
        min_win += 1



print(f'Player1: {(max_win/iter)*100}%')
print(f'Player2: {(min_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       4 iter = 30
#       6 for i in range (iter):
# ----> 7     winner = play(3,8, True)
#       9     if winner == None:
#      10         draw += 1
#
# File ~/WSI_LABS/lab3/play.py:31, in play(depth1, depth2, max_first)
#      28     max_move = False
#      29     depth = depth2
# ---> 31 _, move = minimax(evaluate_move, depth, game.state, max_move, max_player, min_player, float('-inf'), float("inf"))
#      33 game.make_move(move)
#      34 #print(game.state)
#
# File ~/WSI_LABS/lab3/minimax.py:37, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      32 for move in possible_moves:
#      35     new_state = state.make_move(move)
# ---> 37     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      38     if eval_value < min_eval:
#      40         min_eval = eval_value
#
# File ~/WSI_LABS/lab3/minimax.py:17, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      13 for move in possible_moves:
#      15     new_state = state.make_move(move)
# ---> 17     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      18     if eval_value > max_eval:
#      20         max_eval = eval_value
#
# File ~/WSI_LABS/lab3/minimax.py:37, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      32 for move in possible_moves:
#      35     new_state = state.make_move(move)
# ---> 37     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      38     if eval_value < min_eval:
#      40         min_eval = eval_value
#
# File ~/WSI_LABS/lab3/minimax.py:17, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      13 for move in possible_moves:
#      15     new_state = state.make_move(move)
# ---> 17     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      18     if eval_value > max_eval:
#      20         max_eval = eval_value
#
#     [... skipping similar frames: minimax at line 37 (1 times), minimax at line 17 (1 times)]
#
# File ~/WSI_LABS/lab3/minimax.py:37, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      32 for move in possible_moves:
#      35     new_state = state.make_move(move)
# ---> 37     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      38     if eval_value < min_eval:
#      40         min_eval = eval_value
#
# File ~/WSI_LABS/lab3/minimax.py:17, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      13 for move in possible_moves:
#      15     new_state = state.make_move(move)
# ---> 17     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      18     if eval_value > max_eval:
#      20         max_eval = eval_value
#
# File ~/WSI_LABS/lab3/minimax.py:5, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#       3 def minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta):
#       4     if state.is_finished() or depth == 0:
# ----> 5         return evaluation(state, max_player, min_player), None
#       7     possible_moves = state.get_moves()
#       8     random.shuffle(possible_moves)
#
# File ~/WSI_LABS/lab3/evaluation.py:6, in evaluate_move(state, max_player, min_player)
#       5 def evaluate_move(state: ConnectFourState, max_player: Player, min_player: Player) -> int:
# ----> 6     winner = state.get_winner()
#       8     if winner is not None:
#       9         if winner.char == max_player.char:
#
# File ~/WSI_LABS/lab3/two_player_games/games/connect_four.py:78, in ConnectFourState.get_winner(self)
#      76 for column_id in range(len(self.fields)):  # verticals
#      77     for start_row_id in range(len(self.fields[column_id]) - 3):
# ---> 78         winner = self._check_four((column_id, start_row_id), (0, 1))
#      79         if winner:
#      80             return winner
#
# File ~/WSI_LABS/lab3/two_player_games/games/connect_four.py:119, in ConnectFourState._check_four(self, start_coords, move_coords)
#     114 def _check_four(self, start_coords: Tuple[int, int], move_coords: Tuple[int, int]) -> Optional[Player]:
#     115     fields = {
#     116         self.fields[start_coords[0] + move_coords[0] * i][start_coords[1] + move_coords[1] * i] for i in range(4)
#     117     }
# --> 119     if len(fields) != 1:
#     120         return None
#     122     return next(iter(fields))
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Bigger depth for Max

# %%
max_win = 0
min_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(7,4, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        max_win += 1

    else:
        min_win += 1



print(f'Player1: {(max_win/iter)*100}%')
print(f'Player2: {(min_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# Player1: 70.0%
# Player2: 23.333333333333332%
# Draw: 6.666666666666667%

# %%
max_win = 0
min_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(8,3, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        max_win += 1

    else:
        min_win += 1



print(f'Player1: {(max_win/iter)*100}%')
print(f'Player2: {(min_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 7
#       4 iter = 30
#       6 for i in range (iter):
# ----> 7     winner = play(8,3, True)
#       9     if winner == None:
#      10         draw += 1
#
# File ~/WSI_LABS/lab3/play.py:31, in play(depth1, depth2, max_first)
#      28     max_move = False
#      29     depth = depth2
# ---> 31 _, move = minimax(evaluate_move, depth, game.state, max_move, max_player, min_player, float('-inf'), float("inf"))
#      33 game.make_move(move)
#      34 #print(game.state)
#
# File ~/WSI_LABS/lab3/minimax.py:17, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      13 for move in possible_moves:
#      15     new_state = state.make_move(move)
# ---> 17     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      18     if eval_value > max_eval:
#      20         max_eval = eval_value
#
# File ~/WSI_LABS/lab3/minimax.py:37, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      32 for move in possible_moves:
#      35     new_state = state.make_move(move)
# ---> 37     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      38     if eval_value < min_eval:
#      40         min_eval = eval_value
#
# File ~/WSI_LABS/lab3/minimax.py:17, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      13 for move in possible_moves:
#      15     new_state = state.make_move(move)
# ---> 17     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      18     if eval_value > max_eval:
#      20         max_eval = eval_value
#
# File ~/WSI_LABS/lab3/minimax.py:37, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      32 for move in possible_moves:
#      35     new_state = state.make_move(move)
# ---> 37     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      38     if eval_value < min_eval:
#      40         min_eval = eval_value
#
#     [... skipping similar frames: minimax at line 17 (1 times), minimax at line 37 (1 times)]
#
# File ~/WSI_LABS/lab3/minimax.py:17, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      13 for move in possible_moves:
#      15     new_state = state.make_move(move)
# ---> 17     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      18     if eval_value > max_eval:
#      20         max_eval = eval_value
#
# File ~/WSI_LABS/lab3/minimax.py:37, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#      32 for move in possible_moves:
#      35     new_state = state.make_move(move)
# ---> 37     eval_value, _ = minimax(evaluation, depth - 1, new_state, not move_max, max_player, min_player, alpha, beta)
#      38     if eval_value < min_eval:
#      40         min_eval = eval_value
#
# File ~/WSI_LABS/lab3/minimax.py:4, in minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta)
#       3 def minimax(evaluation, depth, state, move_max, max_player, min_player, alpha, beta):
# ----> 4     if state.is_finished() or depth == 0:
#       5         return evaluation(state, max_player, min_player), None
#       7     possible_moves = state.get_moves()
#
# File ~/WSI_LABS/lab3/two_player_games/games/connect_four.py:73, in ConnectFourState.is_finished(self)
#      72 def is_finished(self) -> bool:
# ---> 73     return all(map(all, self.fields)) or self.get_winner() is not None
#
# File ~/WSI_LABS/lab3/two_player_games/games/connect_four.py:78, in ConnectFourState.get_winner(self)
#      76 for column_id in range(len(self.fields)):  # verticals
#      77     for start_row_id in range(len(self.fields[column_id]) - 3):
# ---> 78         winner = self._check_four((column_id, start_row_id), (0, 1))
#      79         if winner:
#      80             return winner
#
# File ~/WSI_LABS/lab3/two_player_games/games/connect_four.py:116, in ConnectFourState._check_four(self, start_coords, move_coords)
#     114 def _check_four(self, start_coords: Tuple[int, int], move_coords: Tuple[int, int]) -> Optional[Player]:
#     115     fields = {
# --> 116         self.fields[start_coords[0] + move_coords[0] * i][start_coords[1] + move_coords[1] * i] for i in range(4)
#     117     }
#     119     if len(fields) != 1:
#     120         return None
#
# KeyboardInterrupt:
