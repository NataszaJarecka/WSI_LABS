# %% [markdown]
# ### Winning ratio with same search depths

# %% [markdown]
# ##### Max first

# %%
from play import play


pl1_win = 0
pl2_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(7,7, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        pl1_win += 1

    else:
        pl2_win += 1


print("Max was first")
print(f'Player1: {(pl1_win/iter)*100}%')
print(f'Player2: {(pl2_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# Max was first
# Player1: 50.0%
# Player2: 46.666666666666664%
# Draw: 3.3333333333333335%

# %%
from play import play


pl1_win = 0
pl2_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(4,4, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        pl1_win += 1

    else:
        pl2_win += 1


print("Max was first")
print(f'Player1: {(pl1_win/iter)*100}%')
print(f'Player2: {(pl2_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# Max was first
# Player1: 50.0%
# Player2: 36.666666666666664%
# Draw: 13.333333333333334%

# %% [markdown]
# #### Random moves

# %%
import random
from two_player_games.player import Player
from two_player_games.games.connect_four import ConnectFourMove, ConnectFour, ConnectFourState

pl1_win = 0
pl2_win = 0
draw = 0
iter = 1000

for i in range(iter):
    player1 = Player("1")
    player2 = Player("2")
    game = ConnectFour((7,6), player1, player2)


    while not game.is_finished():

        index = random.randint(0,6)
        move = ConnectFourMove(index)
        game.make_move(move)


    winner = game.get_winner()

    if winner == None:
        draw += 1

    elif winner.char == "1":
        pl1_win += 1

    else:
        pl2_win += 1

print(f'Player1: {(pl1_win/iter)*100}%')
print(f'Player2: {(pl2_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# Player1: 55.00000000000001%
# Player2: 44.800000000000004%
# Draw: 0.2%

# %% [markdown]
# #### Bigger depth for min

# %%
max_win = 0
min_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(4,7, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        max_win += 1

    else:
        min_win += 1



print(f'Player1: {(max_win/iter)*100}%')
print(f'Player2: {(min_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# Player1: 20.0%
# Player2: 66.66666666666666%
# Draw: 13.333333333333334%

# %%
max_win = 0
min_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(3,8, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        max_win += 1

    else:
        min_win += 1



print(f'Player1: {(max_win/iter)*100}%')
print(f'Player2: {(min_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# Player1: 10.0%
# Player2: 90.0%
# Draw: 0.0%

# %% [markdown]
# ##### Bigger depth for Max

# %%
max_win = 0
min_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(7,4, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        max_win += 1

    else:
        min_win += 1



print(f'Player1: {(max_win/iter)*100}%')
print(f'Player2: {(min_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# Player1: 70.0%
# Player2: 23.333333333333332%
# Draw: 6.666666666666667%

# %%
max_win = 0
min_win = 0
draw = 0
iter = 30

for i in range (iter):
    winner = play(8,3, True)

    if winner == None:
        draw += 1

    elif winner.char == "1":
        max_win += 1

    else:
        min_win += 1



print(f'Player1: {(max_win/iter)*100}%')
print(f'Player2: {(min_win/iter)*100}%')
print(f'Draw: {(draw/iter)*100}%')
# Out:
# Player1: 80.0%
# Player2: 20.0%
# Draw: 0.0%
