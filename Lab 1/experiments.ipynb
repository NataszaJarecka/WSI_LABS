# %% [markdown]
# ## Searching for minimum of $f(x)$

# %%
from gradient_descent_algorythm import gradient_descent
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np
from config_data import (
    F, X, Y_F, X1, X2, Y_G, F_VARIABLES, F_ITER, F_PRESICION, G_VARIABLES, G_PRECISION, G_ITER, G
)

step = 0.005
start = [-2]

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRESICION, F_ITER)

print(f'Minimum in x = {point}, found in {i} iterations')

# visualisation

all_points = np.array(all_points)

y_points = F(all_points)

plt.plot(X, Y_F, label=str(F))

plt.plot(all_points, y_points, marker='o', linestyle='-', color='r', label="Path of gradient", markersize=4)


plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(-50, 30)
plt.xlim(-2.5, 0.5)
plt.title("Plot of f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")


plt.show()
# Out:
# Minimum in x = [-1.41237061], found in 14 iterations

# %% [markdown]
# ### Different step size for different starting points:

# %% [markdown]
# Wide range of points:

# %%
import random

rnd_int = random.uniform(-100, 100)

step = 0.0001

start = [rnd_int]

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRESICION, F_ITER)

print(f'Minimum in x = {point}, found in {i} iterations, starting point was {start}')
# Out:
# Minimum in x = [-inf], found in 6 iterations, starting point was [-98.43398827305774]
# <lambdifygenerated-2>:2: RuntimeWarning: overflow encountered in scalar power
#   return [40*x**3 + 9*x**2 - 60*x + 10]
# <lambdifygenerated-2>:2: RuntimeWarning: invalid value encountered in scalar add
#   return [40*x**3 + 9*x**2 - 60*x + 10]

# %% [markdown]
# Small step:

# %%
rnd_int = random.uniform(-2, 1.5)

step = 0.00003

start = [rnd_int]

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRESICION, F_ITER)

print(f'Minimum in x = {point}, found in {i} iterations, starting point was {start}')

# visualisation

all_points = np.array(all_points)

y_points = F(all_points)

plt.plot(X, Y_F, label=str(F))

plt.plot(all_points, y_points, marker='o', linestyle='-', color='r', markersize=4)


plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(-50, 30)
plt.xlim(-3, 3)
plt.title("Plot of f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")

plt.show()
# Out:
# Minimum in x = [-1.41237061], found in 4234 iterations, starting point was [-0.6961119362937085]

# %% [markdown]
# Big step:

# %%
rnd_int = random.uniform(-2, 1.5)

step = 0.05

start = [rnd_int]

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRESICION, F_ITER)

print(f'Minimum in x = {point}, found in {i} iterations, starting point was {start}')

# visualisation

all_points = np.array(all_points)

y_points = F(all_points)

plt.plot(X, Y_F, label=str(F))

plt.plot(all_points, y_points, marker='o', linestyle='-', color='r', markersize=4)


plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(-50, 30)
plt.xlim(-3, 3)
plt.title("Plot of f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")

plt.show()
# Out:
# Minimum in x = [-inf], found in 8 iterations, starting point was [-0.007516065020381157]
# <lambdifygenerated-4>:2: RuntimeWarning: overflow encountered in scalar power
#   return [40*x**3 + 9*x**2 - 60*x + 10]
# <lambdifygenerated-4>:2: RuntimeWarning: invalid value encountered in scalar add
#   return [40*x**3 + 9*x**2 - 60*x + 10]
# /home/natasza/WSI_LABS/Lab 1/config_data.py:6: RuntimeWarning: overflow encountered in power
#   F = lambda x: 10*x**4 + 3*x**3 - 30*x**2 + 10*x
# /home/natasza/WSI_LABS/Lab 1/config_data.py:6: RuntimeWarning: invalid value encountered in add
#   F = lambda x: 10*x**4 + 3*x**3 - 30*x**2 + 10*x

# %% [markdown]
# Medium step:

# %%
rnd_int = random.uniform(-2, 1.5)

step = 0.01

start = [rnd_int]

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRESICION, F_ITER)

print(f'Minimum in x = {point}, found in {i} iterations, starting point was {start}')

# visualisation

all_points = np.array(all_points)

y_points = F(all_points)

plt.plot(X, Y_F, label=str(F))

plt.plot(all_points, y_points, marker='o', linestyle='-', color='r', markersize=4)


plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(-50, 30)
plt.xlim(-3, 3)
plt.title("Plot of f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")

plt.show()
# Out:
# Minimum in x = [-1.41237062], found in 29 iterations, starting point was [-1.8153365649883422]

# %% [markdown]
# Oscillations

# %%
step = 0.02

start = [-0.5]

iter = 50

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRESICION, iter)

print(f'Minimum in x = {point}, found in {i} iterations, starting point was {start}')

# visualisation

all_points = np.array(all_points)

y_points = F(all_points)

plt.plot(X, Y_F, label=str(F))

plt.plot(all_points, y_points, marker='o', linestyle='-', color='r', markersize=4)


plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(-50, 30)
plt.xlim(-3, 3)
plt.title("Plot of f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")

plt.show()
# Out:
# Minimum in x = [-1.39376128], found in 50 iterations, starting point was [-0.5]

# %% [markdown]
# ## Searching for minimum of $g(x_1, x_2)$

# %%
step = 0.0001
start = [-20, -40]


point, i, all_points = gradient_descent(G, G_VARIABLES, step, start, G_PRECISION, G_ITER)

print(f'Minimum in x = {point}, found in {i} iterations')

all_points = np.array(all_points)

points_x1 = np.array([point[0] for point in all_points])
points_x2 = np.array([point[1] for point in all_points])

plt.figure(figsize=(10, 7))
contour = plt.contourf(X1, X2, Y_G, levels=30, cmap='viridis')
plt.colorbar(contour)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Contour map of $g(x_1, x_2)$')

plt.scatter(points_x1, points_x2, color='red', s=10, label='Punkty')
plt.plot(points_x1, points_x2, color='red', linewidth=2, linestyle='--')


plt.show()
# Out:
# Minimum in x = [ 1.81943645 -3.30367506], found in 10000 iterations

# %% [markdown]
# small step:

# %%
a = random.uniform(-25, 25)
b = random.uniform(-25, 25)


step = 0.0000001
start = [a,b]


point, i, all_points = gradient_descent(G, G_VARIABLES, step, start, G_PRECISION, G_ITER)

print(f'Minimum in x = {point}, found in {i} iterations')

all_points = np.array(all_points)

points_x1 = np.array([point[0] for point in all_points])
points_x2 = np.array([point[1] for point in all_points])

plt.figure(figsize=(10, 7))
contour = plt.contourf(X1, X2, Y_G, levels=30, cmap='viridis')
plt.colorbar(contour)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Contour map of $g(x_1, x_2)$')

plt.scatter(points_x1, points_x2, color='red', s=10, label='Punkty')
plt.plot(points_x1, points_x2, color='red', linewidth=2, linestyle='--')


plt.show()
# Out:
# Minimum in x = [11.80601288 -3.54030202], found in 10000 iterations

# %% [markdown]
# big step:

# %%
a = random.uniform(-25, 25)
b = random.uniform(-25, 25)

step = 0.002
start = [a, b]


point, i, all_points = gradient_descent(G, G_VARIABLES, step, start, G_PRECISION, G_ITER)

print(f'Minimum in x = {point}, found in {i} iterations')

all_points = np.array(all_points)

points_x1 = np.array([point[0] for point in all_points])
points_x2 = np.array([point[1] for point in all_points])

plt.figure(figsize=(10, 7))
contour = plt.contourf(X1, X2, Y_G, levels=30, cmap='viridis')
plt.colorbar(contour)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Contour map of $g(x_1, x_2)$')

plt.xlim(-50, 50)
plt.ylim(-50, 50)
plt.scatter(points_x1, points_x2, color='red', s=10, label='Punkty')
plt.plot(points_x1, points_x2, color='red', linewidth=2, linestyle='--')


plt.show()
# Out:
# Minimum in x = [ 1.92805569 -3.08551144], found in 10000 iterations
