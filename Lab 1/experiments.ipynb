# %% [markdown]
# ## Searching for minimum of $f(x)$

# %%
from gradient_descent_algorythm import gradient_descent
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np
from config import (
    F, X, Y_F, X1, X2, Y_G, F_VARIABLES, F_ITER, F_PRECISION, G_VARIABLES, G_PRECISION, G_ITER, G, F_GLOBAL_MINIMUM, REPEATS, G_GLOBAL_MINIMUM
)

step = 0.005
start = [-2]

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRECISION, F_ITER)

print(f'Minimum in x = {point}, found in {i} iterations')

# visualisation

all_points = np.array(all_points)

y_points = F(all_points)

plt.plot(X, Y_F, label=str(F))

plt.plot(all_points, y_points, marker='o', linestyle='-', color='r', label="Path of gradient", markersize=4)


plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(-50, 30)
plt.xlim(-2.5, 0.5)
plt.title("Plot of f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")


plt.show()
# Out:
# Minimum in x = [-1.41237058], found in 12 iterations

# %% [markdown]
# ### Different step size for different starting points:

# %% [markdown]
# Wide range of points:

# %%
import random

rnd_int = random.uniform(-100, 100)

step = 0.0001

start = [rnd_int]

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRECISION, F_ITER)

print(f'Minimum in x = {point}, found in {i} iterations, starting point was {start}')
# Out:
# Minimum in x = [-1.41237068], found in 1038 iterations, starting point was [-12.70471416403818]

# %% [markdown]
# Small step:

# %%
rnd_int = random.uniform(-2, 1.5)

step = 0.00003

start = [rnd_int]

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRECISION, F_ITER)

print(f'Minimum in x = {point}, found in {i} iterations, starting point was {start}')

# visualisation

all_points = np.array(all_points)

y_points = F(all_points)

plt.plot(X, Y_F, label=str(F))

plt.plot(all_points, y_points, marker='o', linestyle='-', color='r', markersize=4)


plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(-50, 30)
plt.xlim(-3, 3)
plt.title("Plot of f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")

plt.show()
# Out:
# Minimum in x = [1.01255853], found in 6821 iterations, starting point was [0.48732164154725144]

# %% [markdown]
# Big step:

# %%
rnd_int = random.uniform(-2, 1.5)

step = 0.05

start = [rnd_int]

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRECISION, F_ITER)

print(f'Minimum in x = {point}, found in {i} iterations, starting point was {start}')

# visualisation

all_points = np.array(all_points)

y_points = F(all_points)

plt.plot(X, Y_F, label=str(F))

plt.plot(all_points, y_points, marker='o', linestyle='-', color='r', markersize=4)


plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(-50, 30)
plt.xlim(-3, 3)
plt.title("Plot of f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")

plt.show()
# Out:
# Minimum in x = [-inf], found in 9 iterations, starting point was [-1.5733115558342243]
# <lambdifygenerated-1322>:2: RuntimeWarning: overflow encountered in scalar power
#   return [40*x**3 + 9*x**2 - 60*x + 10]
# <lambdifygenerated-1322>:2: RuntimeWarning: invalid value encountered in scalar add
#   return [40*x**3 + 9*x**2 - 60*x + 10]

# %% [markdown]
# Medium step:

# %%
rnd_int = random.uniform(-2, 1.5)

step = 0.01

start = [rnd_int]

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRECISION, F_ITER)

print(f'Minimum in x = {point}, found in {i} iterations, starting point was {start}')

# visualisation

all_points = np.array(all_points)

y_points = F(all_points)

plt.plot(X, Y_F, label=str(F))

plt.plot(all_points, y_points, marker='o', linestyle='-', color='r', markersize=4)


plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(-50, 30)
plt.xlim(-3, 3)
plt.title("Plot of f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")

plt.show()
# Out:
# Minimum in x = [-1.41237068], found in 24 iterations, starting point was [-0.8140345091602728]

# %% [markdown]
# Oscillations

# %%
step = 0.02

start = [-0.5]

iter = 50

point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRECISION, iter)

print(f'Minimum in x = {point}, found in {i} iterations, starting point was {start}')

# visualisation

all_points = np.array(all_points)

y_points = F(all_points)

plt.plot(X, Y_F, label=str(F))

plt.plot(all_points, y_points, marker='o', linestyle='-', color='r', markersize=4)


plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(-50, 30)
plt.xlim(-3, 3)
plt.title("Plot of f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")

plt.show()
# Out:
# Minimum in x = [-1.39376128], found in 50 iterations, starting point was [-0.5]

# %% [markdown]
# Checking the percentage rate of success of algorithm

# %%
step = 0.005

minima_found = 0



for k in range(REPEATS):

    rnd_int = random.uniform(-2, 1.5)

    start = [rnd_int]

    point, i, all_points = gradient_descent(F, F_VARIABLES, step, start, F_PRECISION, F_ITER)

    if abs(point[0] - F_GLOBAL_MINIMUM) <= F_PRECISION:
        minima_found += 1

print(F'Global minimum found in {(minima_found/REPEATS)*100} % of cases')
# Out:
# Global minimum found in 59.0 % of cases

# %% [markdown]
# ## Searching for minimum of $g(x_1, x_2)$

# %%
step = 0.0001
start = [-20, -40]


point, i, all_points = gradient_descent(G, G_VARIABLES, step, start, G_PRECISION, G_ITER)

print(f'Minimum in x = {point}, found in {i} iterations')

all_points = np.array(all_points)

points_x1 = np.array([point[0] for point in all_points])
points_x2 = np.array([point[1] for point in all_points])

plt.figure(figsize=(10, 7))
contour = plt.contourf(X1, X2, Y_G, levels=30, cmap='viridis')
plt.colorbar(contour)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Contour map of $g(x_1, x_2)$')

plt.scatter(points_x1, points_x2, color='red', s=10, label='Punkty')
plt.plot(points_x1, points_x2, color='red', linewidth=2, linestyle='--')


plt.show()
# Out:
# Minimum in x = [ 1.81943645 -3.30367506], found in 10000 iterations

# %% [markdown]
# small step:

# %%
a = random.uniform(-25, 25)
b = random.uniform(-25, 25)


step = 0.0000001
start = [a,b]


point, i, all_points = gradient_descent(G, G_VARIABLES, step, start, G_PRECISION, G_ITER)

print(f'Minimum in x = {point}, found in {i} iterations')

all_points = np.array(all_points)

points_x1 = np.array([point[0] for point in all_points])
points_x2 = np.array([point[1] for point in all_points])

plt.figure(figsize=(10, 7))
contour = plt.contourf(X1, X2, Y_G, levels=30, cmap='viridis')
plt.colorbar(contour)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Contour map of $g(x_1, x_2)$')

plt.scatter(points_x1, points_x2, color='red', s=10, label='Punkty')
plt.plot(points_x1, points_x2, color='red', linewidth=2, linestyle='--')


plt.show()
# Out:
# Minimum in x = [  0.54877662 -12.23000048], found in 10000 iterations

# %% [markdown]
# big step:

# %%
a = random.uniform(-25, 25)
b = random.uniform(-25, 25)

step = 0.002
start = [a, b]


point, i, all_points = gradient_descent(G, G_VARIABLES, step, start, G_PRECISION, G_ITER)

print(f'Minimum in x = {point}, found in {i} iterations')

all_points = np.array(all_points)

points_x1 = np.array([point[0] for point in all_points])
points_x2 = np.array([point[1] for point in all_points])

plt.figure(figsize=(10, 7))
contour = plt.contourf(X1, X2, Y_G, levels=30, cmap='viridis')
plt.colorbar(contour)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Contour map of $g(x_1, x_2)$')

plt.xlim(-50, 50)
plt.ylim(-50, 50)
plt.scatter(points_x1, points_x2, color='red', s=10, label='Punkty')
plt.plot(points_x1, points_x2, color='red', linewidth=2, linestyle='--')


plt.show()
# Out:
# Minimum in x = [ 2.11636306 -2.93017366], found in 3385 iterations

# %% [markdown]
# Checking the percentage rate of success of algorithm

# %%
step = 0.0001

minima_found = 0


for k in range(REPEATS):

    a = random.uniform(-25, 25)
    b = random.uniform(-25, 25)

    start = [a, b]

    point, i, all_points = gradient_descent(G, G_VARIABLES, step, start, G_PRECISION, G_ITER)

    if np.linalg.norm(point - G_GLOBAL_MINIMUM) <= G_PRECISION:
        minima_found += 1

print(F'Global minimum found in {(minima_found/REPEATS)*100} % of cases with precision {G_PRECISION}')

minima_found = 0

small_precision = 0.5

for k in range(REPEATS):

    a = random.uniform(-25, 25)
    b = random.uniform(-25, 25)

    start = [a, b]

    point, i, all_points = gradient_descent(G, G_VARIABLES, step, start, small_precision, G_ITER)

    if np.linalg.norm(point - G_GLOBAL_MINIMUM) <= small_precision:
        minima_found += 1

print(F'Global minimum found in {(minima_found/REPEATS)*100} % of cases with precision {small_precision}')
# Out:
# <lambdifygenerated-2627>:2: RuntimeWarning: overflow encountered in scalar power
#   return [4*(x1 - 2)**3 + 2*(2*x1 - 4)*(x2 + 3)**2, 2*(x1 - 2)**2*(2*x2 + 6) + 4*(x2 + 3)**3]
# /home/natasza/WSI_LABS/Lab 1/gradient_descent_algorythm.py:18: RuntimeWarning: invalid value encountered in subtract
#   next_point = point - step * grad_value
# <lambdifygenerated-2629>:2: RuntimeWarning: overflow encountered in scalar power
#   return [4*(x1 - 2)**3 + 2*(2*x1 - 4)*(x2 + 3)**2, 2*(x1 - 2)**2*(2*x2 + 6) + 4*(x2 + 3)**3]
# <lambdifygenerated-2629>:2: RuntimeWarning: overflow encountered in scalar multiply
#   return [4*(x1 - 2)**3 + 2*(2*x1 - 4)*(x2 + 3)**2, 2*(x1 - 2)**2*(2*x2 + 6) + 4*(x2 + 3)**3]
# <lambdifygenerated-2633>:2: RuntimeWarning: overflow encountered in scalar power
#   return [4*(x1 - 2)**3 + 2*(2*x1 - 4)*(x2 + 3)**2, 2*(x1 - 2)**2*(2*x2 + 6) + 4*(x2 + 3)**3]
# <lambdifygenerated-2633>:2: RuntimeWarning: overflow encountered in scalar multiply
# ...
